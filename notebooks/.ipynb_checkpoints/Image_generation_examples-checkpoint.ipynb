# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import os

# %%
sys.path.insert(0,'../scripts/Images_generation/')
from images_generator import image_generator_sim, image_generator_real
from images_utils import get_data, shift_gal, peak_detection, draw_images
import cosmos_params

sys.path.insert(0,'../scripts/tools_generation/')
from tools_generation import utils, plot

# %% [markdown]
# # Image generation using parametric models (i.e. simulations)

# %% [markdown]
# ## Generate image of isolated galaxies with brightest centered

# %%
case = 'centered' # centered/ miscentered_0.1/ miscentered_peak/ 
gal_type = 'simulation' #simulation or real/
training_or_test = 'test' # training test validation
isolated_or_blended = 'isolated' #isolated blended
method_shift = 'noshift' # noshift uniform uniform+betaprime
do_peak_detection = False
N_files = 1 # Nb of files to generate
N_per_file = 1 # Number of galaxies per file
nmax_blend = 1 # Number of galaxies on an image if integer, or interval for sampling if tuple
assert training_or_test in ['training', 'validation', 'test']

# Fixed parameters:
max_try = 100 # maximum number of try before leaving the function (to avoir infinite loop)
mag_cut = 27.5 # magnitude cut
max_stamp_size = 64 # Size of patch to generate
center_brightest = True # Center the brightest galaxy (i.e. the galaxy with the highest magnitude)
# If center_brightest = False : choose with method to use to shift the brightest
method_shift_brightest = 'uniform'
# And then you need to choose the method to shift the other galaxies as a function of the position of the brightest on the image
method_shift_others = 'uniform'
max_dx = 3.2 #in arcseconds, limit to use for uniform shifting: the center of the shifted galaxy will be shifted from the center or from the brightest galaxy from a random number between [-max_dx ; max_dx] arcsecond
max_r = 2. #in arcseconds, limit to use for annulus shifting: galaxy is shifted in an annulus around the center of the image or of the brightest galaxy which has for minimum radius fwhm_lsst/2 and for maximum radius max_r

# %%
# Index to use
used_idx = np.arange(5000)
# Catalog path
cosmos_cat_dir = '/sps/lsst/users/barcelin/COSMOS_25.2_training_sample'

# %%
res = image_generator_sim(cosmos_cat_dir, training_or_test, isolated_or_blended, used_idx, nmax_blend, max_try, mag_cut, method_shift_brightest, method_shift_others, max_dx, max_r, do_peak_detection, center_brightest, max_stamp_size)

# %%
res[2]
# Out:
# {'redshift_0': 1.1467000246047974,
#  'moment_sigma_0': 2.2473971843719482,
#  'e1_0': -0.14714209735393524,
#  'e2_0': 0.48778873682022095,
#  'mag_0': 26.954974453280116,
#  'nb_blended_gal': 1,
#  'mag': 26.954974453280116,
#  'mag_ir': -1.8741807765876137,
#  'closest_mag': nan,
#  'closest_mag_ir': nan,
#  'closest_x': nan,
#  'closest_y': nan,
#  'idx_closest_to_peak': 0,
#  'n_peak_detected': 1,
#  'SNR': 30.403293088430136,
#  'SNR_peak': 0.030903539568807384}

# %%
fig, ax = plt.subplots(1,2, figsize =(10,5))
ax[0].imshow(res[0][6])
ax[1].imshow(res[1][6])

# %% [markdown]
# ## Generate image of blended galaxies without brightest centered

# %%
case = 'centered' # centered/ miscentered_0.1/ miscentered_peak/ 
gal_type = 'simulation' #simulation or real/
training_or_test = 'test' # training test validation
isolated_or_blended = 'blended' #isolated blended
method_shift = 'uniform' # noshift uniform uniform+betaprime
do_peak_detection = False
N_files = 1 # Nb of files to generate
N_per_file = 1 # Number of galaxies per file
nmax_blend = 6 # Number of galaxies on an image if integer, or interval for sampling if tuple
assert training_or_test in ['training', 'validation', 'test']

# Fixed parameters:
max_try = 100 # maximum number of try before leaving the function (to avoir infinite loop)
mag_cut = 27.5 # magnitude cut
max_stamp_size = 64 # Size of patch to generate
center_brightest = True # Center the brightest galaxy (i.e. the galaxy with the highest magnitude)
# If center_brightest = False : choose with method to use to shift the brightest
method_shift_brightest = 'uniform'
# And then you need to choose the method to shift the other galaxies as a function of the position of the brightest on the image
method_shift_others = 'uniform'
max_dx = 3.2 #in arcseconds, limit to use for uniform shifting: the center of the shifted galaxy will be shifted from the center or from the brightest galaxy from a random number between [-max_dx ; max_dx] arcsecond
max_r = 2. #in arcseconds, limit to use for annulus shifting: galaxy is shifted in an annulus around the center of the image or of the brightest galaxy which has for minimum radius fwhm_lsst/2 and for maximum radius max_r

# %%
# Index to use
used_idx = np.arange(5000)
# Catalog path
cosmos_cat_dir = '/sps/lsst/users/barcelin/COSMOS_25.2_training_sample'

# %%
res = image_generator_sim(cosmos_cat_dir, training_or_test, isolated_or_blended, used_idx, nmax_blend, max_try, mag_cut, method_shift_brightest, method_shift_others, max_dx, max_r, do_peak_detection, center_brightest)

# %%
res[2]
# Out:
# {'redshift_0': 1.9910000562667847,
#  'moment_sigma_0': 1.8468996286392212,
#  'e1_0': 0.19499900937080383,
#  'e2_0': 0.09539693593978882,
#  'mag_0': 27.142304715996513,
#  'redshift_1': 0.8108000159263611,
#  'moment_sigma_1': 2.125153064727783,
#  'e1_1': 0.06250409036874771,
#  'e2_1': 0.3139002323150635,
#  'mag_1': 27.44647839307496,
#  'redshift_2': 0.995199978351593,
#  'moment_sigma_2': 1.9301371574401855,
#  'e1_2': -0.03329276293516159,
#  'e2_2': -0.010579906404018402,
#  'mag_2': 25.94740193304264,
#  'redshift_3': 0.6700999736785889,
#  'moment_sigma_3': 1.9123177528381348,
#  'e1_3': -0.334852933883667,
#  'e2_3': 0.27861782908439636,
#  'mag_3': 27.17010871438697,
#  'redshift_4': 2.481800079345703,
#  'moment_sigma_4': 1.6342451572418213,
#  'e1_4': 0.24876295030117035,
#  'e2_4': -0.26420897245407104,
#  'mag_4': 27.438394258139866,
#  'redshift_5': 0.6608999967575073,
#  'moment_sigma_5': 1.611521601676941,
#  'e1_5': -0.014862020500004292,
#  'e2_5': 0.07302644103765488,
#  'mag_5': 26.656356643134917,
#  'nb_blended_gal': 6,
#  'mag': 25.94740193304264,
#  'mag_ir': -2.5022578788089227,
#  'closest_mag': 27.17010871438697,
#  'closest_mag_ir': -0.3314640425440105,
#  'closest_x': 1.4604949927654323,
#  'closest_y': 0.8409642991707802,
#  'idx_closest_to_peak': 0,
#  'n_peak_detected': 1,
#  'SNR': 90.24414270999785,
#  'SNR_peak': 0.10394286255214205}

# %%
fig, ax = plt.subplots(1,2, figsize =(10,5))
ax[0].imshow(res[0][6])
ax[1].imshow(res[1][6])

# %% [markdown]
# Now if I want an image with a variable number of galaxies, say between 2 and 5, I need to set the 'nmax_blend' parameter to (2,5).

# %%
nmax_blend = (2,5) # Give an interval to sample the number of galaxies to add in this interval

# %%
res = image_generator_sim(cosmos_cat_dir, training_or_test, isolated_or_blended, used_idx, nmax_blend, max_try, mag_cut, method_shift_brightest, method_shift_others, max_dx, max_r, do_peak_detection, center_brightest)

# %%
res[2]
# Out:
# {'redshift_0': 0.22699999809265137,
#  'moment_sigma_0': 2.4930310249328613,
#  'e1_0': 0.1319952756166458,
#  'e2_0': -0.07012245804071426,
#  'mag_0': 24.623220402922314,
#  'redshift_1': 4.311500072479248,
#  'moment_sigma_1': 1.8938792943954468,
#  'e1_1': -0.011850573122501373,
#  'e2_1': -0.415676087141037,
#  'mag_1': 27.391562317390143,
#  'redshift_2': 0.6732000112533569,
#  'moment_sigma_2': 1.8053687810897827,
#  'e1_2': 0.35811665654182434,
#  'e2_2': 0.4033950865268707,
#  'mag_2': 25.62847577710367,
#  'redshift_3': 0.9919999837875366,
#  'moment_sigma_3': 2.001284122467041,
#  'e1_3': 0.13943150639533997,
#  'e2_3': 0.0009679035283625126,
#  'mag_3': 26.331592377861167,
#  'redshift_4': 10.0,
#  'moment_sigma_4': 10.0,
#  'e1_4': 10.0,
#  'e2_4': 10.0,
#  'mag_4': 10.0,
#  'nb_blended_gal': 4,
#  'mag': 24.623220402922314,
#  'mag_ir': -2.133794186553157,
#  'closest_mag': 26.331592377861167,
#  'closest_mag_ir': -1.69277571999345,
#  'closest_x': 1.834709772089055,
#  'closest_y': 0.8974817499370715,
#  'idx_closest_to_peak': 0,
#  'n_peak_detected': 1,
#  'SNR': 220.76787460104077,
#  'SNR_peak': 0.21708374868712013}

# %%
fig, ax = plt.subplots(1,2, figsize =(10,5))
ax[0].imshow(res[0][6])
ax[1].imshow(res[1][6])

# %% [markdown]
# # Image generation using real galaxy images (brightest not centered)

# %% [markdown]
# A small correlated noise is observed on these 'denoised' real images.
# A procedure exists in GalSim to whiten the noise but is still not functionning yet. An issue is opened about this: https://github.com/GalSim-developers/GalSim/issues/1071
#
#
# Important: If the parameter 'center_brightest' is set to 'False', the brightest galaxy is not centered any more but also the first parameters at rank 0 in the data do not refer to the brightest galaxy any more. It is the case when 'center_brightest' is set to 'True'.

# %% [markdown]
# ## Generate image of isolated galaxies

# %%
case = 'centered' # centered/ miscentered_0.1/ miscentered_peak/ 
gal_type = 'real' #simulation or real/
training_or_test = 'test' # training test validation
isolated_or_blended = 'isolated' #isolated blended
method_shift = 'noshift' # noshift uniform uniform+betaprime
do_peak_detection = False
N_files = 1 # Nb of files to generate
N_per_file = 1 # Number of galaxies per file
nmax_blend = 1 # Number of galaxies on an image if integer, or interval for sampling if tuple
assert training_or_test in ['training', 'validation', 'test']

# Fixed parameters:
max_try = 100 # maximum number of try before leaving the function (to avoir infinite loop)
mag_cut = 26. # magnitude cut
max_stamp_size = 64 # Size of patch to generate
center_brightest = False # Center the brightest galaxy (i.e. the galaxy with the highest magnitude)
# If center_brightest = False : choose with method to use to shift the brightest
method_shift_brightest = 'uniform'
# And then you need to choose the method to shift the other galaxies as a function of the position of the brightest on the image
method_shift_others = 'uniform'
max_dx = 3.2 #in arcseconds, limit to use for uniform shifting: the center of the shifted galaxy will be shifted from the center or from the brightest galaxy from a random number between [-max_dx ; max_dx] arcsecond
max_r = 2. #in arcseconds, limit to use for annulus shifting: galaxy is shifted in an annulus around the center of the image or of the brightest galaxy which has for minimum radius fwhm_lsst/2 and for maximum radius max_r

# %%
# Index to use
used_idx = np.arange(5000)
# Catalog path
cosmos_cat_dir = '/sps/lsst/users/barcelin/COSMOS_25.2_training_sample'

# %%
res = image_generator_real(cosmos_cat_dir, training_or_test, isolated_or_blended, used_idx, nmax_blend, max_try, mag_cut, method_shift_brightest, method_shift_others, max_dx, max_r, do_peak_detection, center_brightest, max_stamp_size)

# %%
res[2]
# Out:
# {'mag_0': 25.066547195011065,
#  'redshift_0': 0.0,
#  'moment_sigma_0': 3.5749447345733643,
#  'e1_0': 0.7969626188278198,
#  'e2_0': -0.4234820604324341,
#  'nb_blended_gal': 1,
#  'mag': 25.066547195011065,
#  'mag_ir': -2.2757504951837584,
#  'closest_mag': nan,
#  'closest_mag_ir': nan,
#  'closest_x': nan,
#  'closest_y': nan,
#  'idx_closest_to_peak': 0,
#  'n_peak_detected': 1,
#  'SNR': 120.11093062043449,
#  'SNR_peak': 0.08407415069878255}

# %%
fig, ax = plt.subplots(1,2, figsize =(10,5))
ax[0].imshow(res[0][6])
ax[1].imshow(res[1][6])

# %% [markdown]
# ## Generate image of blended galaxies

# %%
case = 'centered' # centered/ miscentered_0.1/ miscentered_peak/ 
gal_type = 'real' #simulation or real/
training_or_test = 'test' # training test validation
isolated_or_blended = 'blended' #isolated blended
method_shift = 'uniform' # noshift uniform uniform+betaprime
do_peak_detection = False
N_files = 1 # Nb of files to generate
N_per_file = 1 # Number of galaxies per file
nmax_blend = 6 # Number of galaxies on an image if integer, or interval for sampling if tuple
assert training_or_test in ['training', 'validation', 'test']

# Fixed parameters:
max_try = 100 # maximum number of try before leaving the function (to avoir infinite loop)
mag_cut = 26 # magnitude cut
max_stamp_size = 64 # Size of patch to generate
center_brightest = True # Center the brightest galaxy (i.e. the galaxy with the highest magnitude)
# If center_brightest = False : choose with method to use to shift the brightest
method_shift_brightest = 'uniform'
# And then you need to choose the method to shift the other galaxies as a function of the position of the brightest on the image
method_shift_others = 'annulus'
max_dx = 3.2 #in arcseconds, limit to use for uniform shifting: the center of the shifted galaxy will be shifted from the center or from the brightest galaxy from a random number between [-max_dx ; max_dx] arcsecond
max_r = 4. #in arcseconds, limit to use for annulus shifting: galaxy is shifted in an annulus around the center of the image or of the brightest galaxy which has for minimum radius fwhm_lsst/2 and for maximum radius max_r

# %%
# Index to use
used_idx = np.arange(5000)
# Catalog path
cosmos_cat_dir = '/sps/lsst/users/barcelin/COSMOS_25.2_training_sample'

# %%
res = image_generator_real(cosmos_cat_dir, training_or_test, isolated_or_blended, used_idx, nmax_blend, max_try, mag_cut, method_shift_brightest, method_shift_others, max_dx, max_r, do_peak_detection, center_brightest, max_stamp_size)

# %%
res[2]
# Out:
# {'mag_0': 25.60612799475513,
#  'redshift_0': 0.0,
#  'moment_sigma_0': 1.7292624711990356,
#  'e1_0': -0.0584578700363636,
#  'e2_0': -0.026906313374638557,
#  'mag_1': 24.92527164174407,
#  'redshift_1': 0.0,
#  'moment_sigma_1': 2.2249648571014404,
#  'e1_1': -0.3708880841732025,
#  'e2_1': -0.16338959336280823,
#  'mag_2': 23.22365906987831,
#  'redshift_2': 0.0,
#  'moment_sigma_2': 3.756402015686035,
#  'e1_2': 0.11650899797677994,
#  'e2_2': -0.22796298563480377,
#  'mag_3': 24.310185597982755,
#  'redshift_3': 0.0,
#  'moment_sigma_3': 1.9432724714279175,
#  'e1_3': 0.09170732647180557,
#  'e2_3': 0.05151541531085968,
#  'mag_4': 25.555005149364607,
#  'redshift_4': 0.0,
#  'moment_sigma_4': 2.4459774494171143,
#  'e1_4': 0.14638549089431763,
#  'e2_4': -0.054716117680072784,
#  'mag_5': 25.34895954840933,
#  'redshift_5': 0.0,
#  'moment_sigma_5': 2.988701343536377,
#  'e1_5': -0.09321140497922897,
#  'e2_5': 0.015350205823779106,
#  'nb_blended_gal': 6,
#  'mag': 23.22365906987831,
#  'mag_ir': -3.665983226622515,
#  'closest_mag': 24.310185597982755,
#  'closest_mag_ir': -4.3029065038237535,
#  'closest_x': -0.39731446000771387,
#  'closest_y': -0.33488761435740555,
#  'idx_closest_to_peak': 0,
#  'n_peak_detected': 1,
#  'SNR': 490.169605794321,
#  'SNR_peak': 0.3853676470799298}

# %%
fig, ax = plt.subplots(1,2, figsize =(10,5))
ax[0].imshow(res[0][6])
ax[1].imshow(res[1][6])

# %% [markdown]
# # Image generation of field

# %% [markdown]
#  51.2 arcseconds of LSST (256x256 pixels, 256 x 0.2 = 51.2 - 0.2 arcsecond/pix is pixel size of LSST data), so shift in 51.2/2 = 25,6 arcseconds.
#
#  On these field I add a random number between 32 and 96 galaxies so that, if we generate a lot of these, the mean is at 64 galaxies per patch (mean of galaxies density after 10 years of operation for LSST, https://arxiv.org/pdf/1911.02505.pdf, part 2.4 page 4)

# %%
case = 'centered' # centered/ miscentered_0.1/ miscentered_peak/ 
gal_type = 'simulation' #simulation or real/
training_or_test = 'test' # training test validation
isolated_or_blended = 'blended' #isolated blended
method_shift = 'uniform' # noshift uniform uniform+betaprime
do_peak_detection = False
N_files = 1 # Nb of files to generate
N_per_file = 1 # Number of galaxies per file
nmax_blend = (32,96) # Number of galaxies on an image if integer, or interval for sampling if tuple
assert training_or_test in ['training', 'validation', 'test']

# Fixed parameters:
max_try = 100 # maximum number of try before leaving the function (to avoir infinite loop)
mag_cut = 27.5 # magnitude cut
max_stamp_size = 256 # Size of patch to generate
center_brightest = False # Center the brightest galaxy (i.e. the galaxy with the highest magnitude)
# If center_brightest = False : choose with method to use to shift the brightest
method_shift_brightest = 'uniform'
# And then you need to choose the method to shift the other galaxies as a function of the position of the brightest on the image
method_shift_others = 'uniform'
max_dx = 25.6 #in arcseconds, limit to use for uniform shifting: the center of the shifted galaxy will be shifted from the center or from the brightest galaxy from a random number between [-max_dx ; max_dx] arcsecond
max_r = 4. #in arcseconds, limit to use for annulus shifting: galaxy is shifted in an annulus around the center of the image or of the brightest galaxy which has for minimum radius fwhm_lsst/2 and for maximum radius max_r

# %%
# Index to use
used_idx = np.arange(5000)
# Catalog path
cosmos_cat_dir = '/sps/lsst/users/barcelin/COSMOS_25.2_training_sample'

# %% [markdown]
# ## With simulations

# %%
res = image_generator_sim(cosmos_cat_dir, training_or_test, isolated_or_blended, used_idx, nmax_blend, max_try, mag_cut, method_shift_brightest, method_shift_others, max_dx, max_r, do_peak_detection, center_brightest, max_stamp_size)

# %%
res[2]
# Out:
# {'redshift_0': 0.6394000053405762,
#  'moment_sigma_0': 2.070451498031616,
#  'e1_0': 0.1941514015197754,
#  'e2_0': 0.22619009017944336,
#  'mag_0': 26.896208746578065,
#  'redshift_1': 1.8172999620437622,
#  'moment_sigma_1': 1.8433659076690674,
#  'e1_1': 0.19181261956691742,
#  'e2_1': -0.13894763588905334,
#  'mag_1': 26.65976879340851,
#  'redshift_2': 1.1058000326156616,
#  'moment_sigma_2': 1.900357723236084,
#  'e1_2': 0.43330860137939453,
#  'e2_2': 0.2400633543729782,
#  'mag_2': 26.590053369666805,
#  'redshift_3': 0.8001999855041504,
#  'moment_sigma_3': 2.197740316390991,
#  'e1_3': -0.08336246013641357,
#  'e2_3': 0.0073847114108502865,
#  'mag_3': 25.90674248902084,
#  'redshift_4': 0.8888000249862671,
#  'moment_sigma_4': 2.2047500610351562,
#  'e1_4': -0.5488321185112,
#  'e2_4': 0.08059462904930115,
#  'mag_4': 27.412460647210793,
#  'redshift_5': 0.6252999901771545,
#  'moment_sigma_5': 1.9880280494689941,
#  'e1_5': 0.530240535736084,
#  'e2_5': 0.5086889863014221,
#  'mag_5': 26.31765405408009,
#  'redshift_6': 0.6732000112533569,
#  'moment_sigma_6': 1.8053640127182007,
#  'e1_6': 0.17960546910762787,
#  'e2_6': 0.5086358785629272,
#  'mag_6': 25.62847577710367,
#  'redshift_7': 2.828000068664551,
#  'moment_sigma_7': 1.745743751525879,
#  'e1_7': -0.09806783497333527,
#  'e2_7': 0.12377694994211197,
#  'mag_7': 26.974747896613355,
#  'redshift_8': 0.1429000049829483,
#  'moment_sigma_8': 1.8840904235839844,
#  'e1_8': -0.10245748609304428,
#  'e2_8': -0.16484133899211884,
#  'mag_8': 26.18840424227095,
#  'redshift_9': 0.934499979019165,
#  'moment_sigma_9': 2.0963947772979736,
#  'e1_9': 0.04219425469636917,
#  'e2_9': 0.19325494766235352,
#  'mag_9': 26.451926935330093,
#  'redshift_10': 2.0550999641418457,
#  'moment_sigma_10': 2.0759220123291016,
#  'e1_10': 0.08441656082868576,
#  'e2_10': -0.2203359603881836,
#  'mag_10': 26.131840721505274,
#  'redshift_11': 2.609499931335449,
#  'moment_sigma_11': 1.7285513877868652,
#  'e1_11': 0.13141939043998718,
#  'e2_11': 0.3789476156234741,
#  'mag_11': 27.269066598820768,
#  'redshift_12': 0.18649999797344208,
#  'moment_sigma_12': 3.335648775100708,
#  'e1_12': 0.4161016345024109,
#  'e2_12': -0.008570453152060509,
#  'mag_12': 25.101051995694554,
#  'redshift_13': 0.3167000114917755,
#  'moment_sigma_13': 3.360611915588379,
#  'e1_13': 0.5094011425971985,
#  'e2_13': 0.5884127020835876,
#  'mag_13': 22.375715959307446,
#  'redshift_14': 2.5761001110076904,
#  'moment_sigma_14': 1.9486048221588135,
#  'e1_14': -0.11511524021625519,
#  'e2_14': -0.3163716197013855,
#  'mag_14': 26.77447156674921,
#  'redshift_15': 1.5111000537872314,
#  'moment_sigma_15': 1.8607196807861328,
#  'e1_15': 0.4432244300842285,
#  'e2_15': -0.418381929397583,
#  'mag_15': 27.03078536099612,
#  'redshift_16': 2.0190000534057617,
#  'moment_sigma_16': 2.3143699169158936,
#  'e1_16': 0.18059097230434418,
#  'e2_16': 0.369146466255188,
#  'mag_16': 25.968954531973765,
#  'redshift_17': 1.205899953842163,
#  'moment_sigma_17': 2.3337631225585938,
#  'e1_17': -0.012072395533323288,
#  'e2_17': -0.048587165772914886,
#  'mag_17': 26.430568864674903,
#  'redshift_18': 0.6629999876022339,
#  'moment_sigma_18': 1.8723602294921875,
#  'e1_18': 0.21265852451324463,
#  'e2_18': 0.0069799344055354595,
#  'mag_18': 27.213177973359702,
#  'redshift_19': 1.3248000144958496,
#  'moment_sigma_19': 1.9992287158966064,
#  'e1_19': 0.27926313877105713,
#  'e2_19': -0.06650368869304657,
#  'mag_19': 27.203372573325147,
#  'redshift_20': 0.5932000279426575,
#  'moment_sigma_20': 1.9957059621810913,
#  'e1_20': -0.6066417098045349,
#  'e2_20': -0.1915547400712967,
#  'mag_20': 26.489978142131335,
#  'redshift_21': 1.205899953842163,
#  'moment_sigma_21': 2.333763360977173,
#  'e1_21': -0.04937082529067993,
#  'e2_21': -0.008317521773278713,
#  'mag_21': 26.430568864674903,
#  'redshift_22': 0.7430999875068665,
#  'moment_sigma_22': 2.079359769821167,
#  'e1_22': -0.00117857928853482,
#  'e2_22': -0.06574378907680511,
#  'mag_22': 26.158427518645755,
#  'redshift_23': 0.6269000172615051,
#  'moment_sigma_23': 1.707423210144043,
#  'e1_23': 0.3767157793045044,
#  'e2_23': 0.3813447952270508,
#  'mag_23': 27.466154603937362,
#  'redshift_24': 0.8413000106811523,
#  'moment_sigma_24': 2.1528966426849365,
#  'e1_24': 0.38662049174308777,
#  'e2_24': -0.43162599205970764,
#  'mag_24': 26.35910544734264,
#  'redshift_25': 0.4124999940395355,
#  'moment_sigma_25': 2.4126760959625244,
#  'e1_25': -0.3413323163986206,
#  'e2_25': -0.08974312990903854,
#  'mag_25': 26.12447021598434,
#  'redshift_26': 1.0196000337600708,
#  'moment_sigma_26': 1.9502177238464355,
#  'e1_26': 0.37197738885879517,
#  'e2_26': 0.30850401520729065,
#  'mag_26': 27.079091124799078,
#  'redshift_27': 2.676100015640259,
#  'moment_sigma_27': 1.74019193649292,
#  'e1_27': 0.3145340085029602,
#  'e2_27': -0.2504112124443054,
#  'mag_27': 27.34092811278259,
#  'redshift_28': 0.7084000110626221,
#  'moment_sigma_28': 2.026442766189575,
#  'e1_28': 0.02380039542913437,
#  'e2_28': -0.26187193393707275,
#  'mag_28': 25.622392079560385,
#  'redshift_29': 0.8560000061988831,
#  'moment_sigma_29': 1.9876197576522827,
#  'e1_29': -0.21599256992340088,
#  'e2_29': 0.03282070532441139,
#  'mag_29': 26.548730182693152,
#  'redshift_30': 0.8946999907493591,
#  'moment_sigma_30': 2.0499215126037598,
#  'e1_30': 0.08139762282371521,
#  'e2_30': 0.08773678541183472,
#  'mag_30': 25.904443084747292,
#  'redshift_31': 3.3536999225616455,
#  'moment_sigma_31': 1.5314502716064453,
#  'e1_31': -0.20957738161087036,
#  'e2_31': -0.36936965584754944,
#  'mag_31': 27.248492067144014,
#  'redshift_32': 0.16300000250339508,
#  'moment_sigma_32': 2.4384145736694336,
#  'e1_32': 0.03234356641769409,
#  'e2_32': -0.050527118146419525,
#  'mag_32': 26.25798557245874,
#  'redshift_33': 1.3707000017166138,
#  'moment_sigma_33': 1.697235107421875,
#  'e1_33': -0.14227227866649628,
#  'e2_33': 0.5399479866027832,
#  'mag_33': 27.267550304458705,
#  'redshift_34': 3.4609999656677246,
#  'moment_sigma_34': 1.6031523942947388,
#  'e1_34': 0.10982134193181992,
#  'e2_34': -0.27275338768959045,
#  'mag_34': 27.1376538086443,
#  'redshift_35': 3.015899896621704,
#  'moment_sigma_35': 1.636475920677185,
#  'e1_35': -0.11404601484537125,
#  'e2_35': -0.2743228077888489,
#  'mag_35': 27.0841239813033,
#  'redshift_36': 0.25999999046325684,
#  'moment_sigma_36': 2.28228497505188,
#  'e1_36': -0.0796273872256279,
#  'e2_36': -0.4581238627433777,
#  'mag_36': 24.115508952939685,
#  'redshift_37': 1.332900047302246,
#  'moment_sigma_37': 2.8067822456359863,
#  'e1_37': -0.005888316314667463,
#  'e2_37': 0.01010052114725113,
#  'mag_37': 26.611962664725738,
#  'redshift_38': 1.9371000528335571,
#  'moment_sigma_38': 1.6766828298568726,
#  'e1_38': 0.07988718152046204,
#  'e2_38': 0.5145659446716309,
#  'mag_38': 27.39945677304219,
#  'redshift_39': 0.8192999958992004,
#  'moment_sigma_39': 2.0253942012786865,
#  'e1_39': -0.47913438081741333,
#  'e2_39': -0.3836223781108856,
#  'mag_39': 27.02968860136396,
#  'redshift_40': 1.367400050163269,
#  'moment_sigma_40': 1.8032937049865723,
#  'e1_40': -0.15160514414310455,
#  'e2_40': -0.020977545529603958,
#  'mag_40': 27.110262362882175,
#  'redshift_41': 0.2053000032901764,
#  'moment_sigma_41': 2.533040761947632,
#  'e1_41': 0.5668786764144897,
#  'e2_41': -0.08697734028100967,
#  'mag_41': 26.627620506058463,
#  'redshift_42': 0.8686000108718872,
#  'moment_sigma_42': 1.6467292308807373,
#  'e1_42': 0.2870767414569855,
#  'e2_42': -0.25602206587791443,
#  'mag_42': 26.414358763384765,
#  'redshift_43': 0.26010000705718994,
#  'moment_sigma_43': 1.6896873712539673,
#  'e1_43': -0.10324759781360626,
#  'e2_43': -0.44815298914909363,
#  'mag_43': 25.734064457963537,
#  'redshift_44': 1.6482000350952148,
#  'moment_sigma_44': 1.977339506149292,
#  'e1_44': 0.6854038834571838,
#  'e2_44': -0.12181392312049866,
#  'mag_44': 27.400845209222084,
#  'redshift_45': 0.32919999957084656,
#  'moment_sigma_45': 1.9656689167022705,
#  'e1_45': -0.13920600712299347,
#  'e2_45': 0.17524728178977966,
#  'mag_45': 26.143430414297857,
#  'redshift_46': 0.8705999851226807,
#  'moment_sigma_46': 1.8978872299194336,
#  'e1_46': 0.5750607848167419,
#  'e2_46': -0.24168723821640015,
#  'mag_46': 26.766819848346593,
#  'redshift_47': 0.35409998893737793,
#  'moment_sigma_47': 3.174628496170044,
#  'e1_47': -0.2782503068447113,
#  'e2_47': 0.07575134932994843,
#  'mag_47': 23.784947958437705,
#  'redshift_48': 1.0450999736785889,
#  'moment_sigma_48': 1.7617532014846802,
#  'e1_48': -0.08201958984136581,
#  'e2_48': -0.27154797315597534,
#  'mag_48': 26.90531078507711,
#  'redshift_49': 2.2639000415802,
#  'moment_sigma_49': 2.0107526779174805,
#  'e1_49': 0.018717069178819656,
#  'e2_49': 0.025131259113550186,
#  'mag_49': 27.290556474791426,
#  'redshift_50': 0.6251000165939331,
#  'moment_sigma_50': 2.858153820037842,
#  'e1_50': 0.19733336567878723,
#  'e2_50': -1.1054506301879883,
#  'mag_50': 24.99877296292965,
#  'redshift_51': 0.3646000027656555,
#  'moment_sigma_51': 2.850156545639038,
#  'e1_51': 0.25371235609054565,
#  'e2_51': -0.07922763377428055,
#  'mag_51': 23.328345403728072,
#  'redshift_52': 0.44269999861717224,
#  'moment_sigma_52': 2.6849396228790283,
#  'e1_52': 0.550899088382721,
#  'e2_52': 0.2633213996887207,
#  'mag_52': 24.19856845031113,
#  'redshift_53': 0.1251000016927719,
#  'moment_sigma_53': 1.629101276397705,
#  'e1_53': 0.47771120071411133,
#  'e2_53': 0.08139544725418091,
#  'mag_53': 27.457942006532246,
#  'redshift_54': 0.19040000438690186,
#  'moment_sigma_54': 2.6713151931762695,
#  'e1_54': 0.3892790675163269,
#  'e2_54': 0.2972717583179474,
#  'mag_54': 21.610541909307244,
#  'redshift_55': 2.5179998874664307,
#  'moment_sigma_55': 1.611353874206543,
#  'e1_55': 0.07792449742555618,
#  'e2_55': -0.25219541788101196,
#  'mag_55': 27.16173261755821,
#  'redshift_56': 0.44929999113082886,
#  'moment_sigma_56': 2.0304346084594727,
#  'e1_56': 0.609836220741272,
#  'e2_56': -0.2901662588119507,
#  'mag_56': 26.35324675124188,
#  'redshift_57': 1.4881000518798828,
#  'moment_sigma_57': 1.8860939741134644,
#  'e1_57': -0.27338752150535583,
#  'e2_57': -0.06713798642158508,
#  'mag_57': 26.584281463718245,
#  'redshift_58': 0.19040000438690186,
#  'moment_sigma_58': 2.6713106632232666,
#  'e1_58': 0.09379056096076965,
#  'e2_58': 0.4807349443435669,
#  'mag_58': 21.610541909307244,
#  'redshift_59': 2.5690999031066895,
#  'moment_sigma_59': 2.615432024002075,
#  'e1_59': 0.1652761697769165,
#  'e2_59': -0.3641214966773987,
#  'mag_59': 26.48277826654847,
#  'redshift_60': 1.601199984550476,
#  'moment_sigma_60': 2.1063661575317383,
#  'e1_60': -0.635208249092102,
#  'e2_60': -0.2652771770954132,
#  'mag_60': 26.690139716152498,
#  'redshift_61': 0.5296000242233276,
#  'moment_sigma_61': 2.250612735748291,
#  'e1_61': -0.39700576663017273,
#  'e2_61': 0.0776963010430336,
#  'mag_61': 26.597517753015936,
#  'redshift_62': 2.3361001014709473,
#  'moment_sigma_62': 1.637000322341919,
#  'e1_62': -0.02406485192477703,
#  'e2_62': -0.30749014019966125,
#  'mag_62': 27.206540744950946,
#  'redshift_63': 0.6218000054359436,
#  'moment_sigma_63': 1.7476327419281006,
#  'e1_63': -0.479306697845459,
#  'e2_63': 0.2586597502231598,
#  'mag_63': 25.721156477998697,
#  'redshift_64': 0.9215999841690063,
#  'moment_sigma_64': 2.0973098278045654,
#  'e1_64': 0.12323765456676483,
#  'e2_64': 0.03083490952849388,
#  'mag_64': 26.73307993227848,
#  'redshift_65': 0.20280000567436218,
#  'moment_sigma_65': 2.1112122535705566,
#  'e1_65': -0.11099559813737869,
#  'e2_65': 0.21663181483745575,
#  'mag_65': 27.32745453739683,
#  'redshift_66': 1.8789000511169434,
#  'moment_sigma_66': 1.9708664417266846,
#  'e1_66': 0.291442334651947,
#  'e2_66': -0.3504137098789215,
#  'mag_66': 26.907903773134862,
#  'redshift_67': 1.6279000043869019,
#  'moment_sigma_67': 1.825256109237671,
#  'e1_67': 0.012763812206685543,
#  'e2_67': 0.40130046010017395,
#  'mag_67': 26.789734042097013,
#  'redshift_68': 0.4456999897956848,
#  'moment_sigma_68': 2.145188808441162,
#  'e1_68': 0.10792794823646545,
#  'e2_68': 0.11872346699237823,
#  'mag_68': 25.61902734069788,
#  'redshift_69': 1.7718000411987305,
#  'moment_sigma_69': 2.4925849437713623,
#  'e1_69': 0.1837068498134613,
#  'e2_69': 0.222257599234581,
#  'mag_69': 26.06950893575968,
#  'redshift_70': 0.30230000615119934,
#  'moment_sigma_70': 1.8278305530548096,
#  'e1_70': 0.02223142422735691,
#  'e2_70': 0.28744447231292725,
#  'mag_70': 26.755082562260338,
#  'redshift_71': 1.0987000465393066,
#  'moment_sigma_71': 1.79844331741333,
#  'e1_71': -0.11430209130048752,
#  'e2_71': -0.296983003616333,
#  'mag_71': 27.309403100268955,
#  'redshift_72': 1.8222999572753906,
#  'moment_sigma_72': 1.829724907875061,
#  'e1_72': 0.6465961337089539,
#  'e2_72': -0.4603792428970337,
#  'mag_72': 27.337006050200028,
#  'redshift_73': 10.0,
#  'moment_sigma_73': 10.0,
#  'e1_73': 10.0,
#  'e2_73': 10.0,
#  'mag_73': 10.0,
#  'redshift_74': 10.0,
#  'moment_sigma_74': 10.0,
#  'e1_74': 10.0,
#  'e2_74': 10.0,
#  'mag_74': 10.0,
#  'redshift_75': 10.0,
#  'moment_sigma_75': 10.0,
#  'e1_75': 10.0,
#  'e2_75': 10.0,
#  'mag_75': 10.0,
#  'redshift_76': 10.0,
#  'moment_sigma_76': 10.0,
#  'e1_76': 10.0,
#  'e2_76': 10.0,
#  'mag_76': 10.0,
#  'redshift_77': 10.0,
#  'moment_sigma_77': 10.0,
#  'e1_77': 10.0,
#  'e2_77': 10.0,
#  'mag_77': 10.0,
#  'redshift_78': 10.0,
#  'moment_sigma_78': 10.0,
#  'e1_78': 10.0,
#  'e2_78': 10.0,
#  'mag_78': 10.0,
#  'redshift_79': 10.0,
#  'moment_sigma_79': 10.0,
#  'e1_79': 10.0,
#  'e2_79': 10.0,
#  'mag_79': 10.0,
#  'redshift_80': 10.0,
#  'moment_sigma_80': 10.0,
#  'e1_80': 10.0,
#  'e2_80': 10.0,
#  'mag_80': 10.0,
#  'redshift_81': 10.0,
#  'moment_sigma_81': 10.0,
#  'e1_81': 10.0,
#  'e2_81': 10.0,
#  'mag_81': 10.0,
#  'redshift_82': 10.0,
#  'moment_sigma_82': 10.0,
#  'e1_82': 10.0,
#  'e2_82': 10.0,
#  'mag_82': 10.0,
#  'redshift_83': 10.0,
#  'moment_sigma_83': 10.0,
#  'e1_83': 10.0,
#  'e2_83': 10.0,
#  'mag_83': 10.0,
#  'redshift_84': 10.0,
#  'moment_sigma_84': 10.0,
#  'e1_84': 10.0,
#  'e2_84': 10.0,
#  'mag_84': 10.0,
#  'redshift_85': 10.0,
#  'moment_sigma_85': 10.0,
#  'e1_85': 10.0,
#  'e2_85': 10.0,
#  'mag_85': 10.0,
#  'redshift_86': 10.0,
#  'moment_sigma_86': 10.0,
#  'e1_86': 10.0,
#  'e2_86': 10.0,
#  'mag_86': 10.0,
#  'redshift_87': 10.0,
#  'moment_sigma_87': 10.0,
#  'e1_87': 10.0,
#  'e2_87': 10.0,
#  'mag_87': 10.0,
#  'redshift_88': 10.0,
#  'moment_sigma_88': 10.0,
#  'e1_88': 10.0,
#  'e2_88': 10.0,
#  'mag_88': 10.0,
#  'redshift_89': 10.0,
#  'moment_sigma_89': 10.0,
#  'e1_89': 10.0,
#  'e2_89': 10.0,
#  'mag_89': 10.0,
#  'redshift_90': 10.0,
#  'moment_sigma_90': 10.0,
#  'e1_90': 10.0,
#  'e2_90': 10.0,
#  'mag_90': 10.0,
#  'redshift_91': 10.0,
#  'moment_sigma_91': 10.0,
#  'e1_91': 10.0,
#  'e2_91': 10.0,
#  'mag_91': 10.0,
#  'redshift_92': 10.0,
#  'moment_sigma_92': 10.0,
#  'e1_92': 10.0,
#  'e2_92': 10.0,
#  'mag_92': 10.0,
#  'redshift_93': 10.0,
#  'moment_sigma_93': 10.0,
#  'e1_93': 10.0,
#  'e2_93': 10.0,
#  'mag_93': 10.0,
#  'redshift_94': 10.0,
#  'moment_sigma_94': 10.0,
#  'e1_94': 10.0,
#  'e2_94': 10.0,
#  'mag_94': 10.0,
#  'redshift_95': 10.0,
#  'moment_sigma_95': 10.0,
#  'e1_95': 10.0,
#  'e2_95': 10.0,
#  'mag_95': 10.0,
#  'nb_blended_gal': 73,
#  'mag': 26.896208746578065,
#  'mag_ir': -1.531526577534784,
#  'closest_mag': 25.734064457963537,
#  'closest_mag_ir': -1.595376699775528,
#  'closest_x': -0.98873641010535,
#  'closest_y': -2.304961407690918,
#  'idx_closest_to_peak': 0,
#  'n_peak_detected': 1,
#  'SNR': 32.534394092559836,
#  'SNR_peak': 0.03700036300472579}

# %%
print(str(res[2]['nb_blended_gal'])+' galaxies are added to this image.')
# Out:
# 73 galaxies are added to this image.

# %% [markdown]
# Here res[0] is not very interesting to plot. It is just the first galaxy which was generated, not necessarily the brightest one, as we set the parameter center_brightest to False.

# %%
fig, ax = plt.subplots(1,2, figsize =(20,10))
ax[0].imshow(res[1][6])
ax[1].imshow(res[1][6], vmax = 2000)

# %% [markdown]
# Use the plot_rgb function of the plot module to show the image in RGB (IRG bands)

# %%
bands = [7,6,5] # Plot ugrizy

fig = plt.figure(figsize = (10,10))

plot.plot_rgb(res[1]/(np.max(res[1][4:])/10), bands = bands,ax= None, band_first = True,zoom = 1, clip = False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Put a cross on the center of each galaxy with the shift information generated when the image is created.

# %%
bands = [7,6,5] # Plot ugrizy
pixel_scale_lsst = 0.2 # arcsec/pix
fig = plt.figure(figsize = (10,10))

plot.plot_rgb(res[1]/(np.max(res[1][4:])/10), bands = bands,ax= None, band_first = True,zoom = 1, shifts = res[3]/pixel_scale_lsst, clip = False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## With real images

# %%
case = 'centered' # centered/ miscentered_0.1/ miscentered_peak/ 
gal_type = 'real' #simulation or real/
training_or_test = 'test' # training test validation
isolated_or_blended = 'blended' #isolated blended
method_shift = 'uniform' # noshift uniform uniform+betaprime
do_peak_detection = False
N_files = 1 # Nb of files to generate
N_per_file = 1 # Number of galaxies per file
nmax_blend = (32,96) # Number of galaxies on an image if integer, or interval for sampling if tuple
assert training_or_test in ['training', 'validation', 'test']

# Fixed parameters:
max_try = 100 # maximum number of try before leaving the function (to avoir infinite loop)
mag_cut = 24. # magnitude cut
max_stamp_size = 256 # Size of patch to generate
center_brightest = False # Center the brightest galaxy (i.e. the galaxy with the highest magnitude)
# If center_brightest = False : choose with method to use to shift the brightest
method_shift_brightest = 'uniform'
# And then you need to choose the method to shift the other galaxies as a function of the position of the brightest on the image
method_shift_others = 'uniform'
max_dx = 25.6 #in arcseconds, limit to use for uniform shifting: the center of the shifted galaxy will be shifted from the center or from the brightest galaxy from a random number between [-max_dx ; max_dx] arcsecond
max_r = 4. #in arcseconds, limit to use for annulus shifting: galaxy is shifted in an annulus around the center of the image or of the brightest galaxy which has for minimum radius fwhm_lsst/2 and for maximum radius max_r

# %%
# Index to use
used_idx = np.arange(5000)
# Catalog path
cosmos_cat_dir = '/sps/lsst/users/barcelin/COSMOS_25.2_training_sample'

# %%
res = image_generator_real(cosmos_cat_dir, training_or_test, isolated_or_blended, used_idx, nmax_blend, max_try, mag_cut, method_shift_brightest, method_shift_others, max_dx, max_r, do_peak_detection, center_brightest, max_stamp_size)

# %%
res[2]
# Out:
# {'mag_0': 21.643046070746873,
#  'redshift_0': 0.0,
#  'moment_sigma_0': 2.5889947414398193,
#  'e1_0': -0.31979092955589294,
#  'e2_0': -0.3674108386039734,
#  'mag_1': 23.88938824443931,
#  'redshift_1': 0.0,
#  'moment_sigma_1': 2.692193031311035,
#  'e1_1': 0.708131730556488,
#  'e2_1': -0.3572450280189514,
#  'mag_2': 22.866205650578067,
#  'redshift_2': 0.0,
#  'moment_sigma_2': 2.423168897628784,
#  'e1_2': -0.5529364943504333,
#  'e2_2': -0.35571858286857605,
#  'mag_3': 23.67345691017818,
#  'redshift_3': 0.0,
#  'moment_sigma_3': 2.3020994663238525,
#  'e1_3': 0.24409545958042145,
#  'e2_3': -0.3182809352874756,
#  'mag_4': 21.921032668959977,
#  'redshift_4': 0.0,
#  'moment_sigma_4': 2.205923080444336,
#  'e1_4': 0.30695873498916626,
#  'e2_4': -0.020905660465359688,
#  'mag_5': 23.379396339651144,
#  'redshift_5': 0.0,
#  'moment_sigma_5': 3.1391916275024414,
#  'e1_5': 0.5006433725357056,
#  'e2_5': -0.13209331035614014,
#  'mag_6': 23.83790204273633,
#  'redshift_6': 0.0,
#  'moment_sigma_6': 2.103226661682129,
#  'e1_6': 0.2435941994190216,
#  'e2_6': 0.1075114980340004,
#  'mag_7': 23.508440660897776,
#  'redshift_7': 0.0,
#  'moment_sigma_7': 3.7762885093688965,
#  'e1_7': -0.2619997262954712,
#  'e2_7': 0.005587177351117134,
#  'mag_8': 23.05915481194958,
#  'redshift_8': 0.0,
#  'moment_sigma_8': 2.672668218612671,
#  'e1_8': -0.26110702753067017,
#  'e2_8': -0.0604410395026207,
#  'mag_9': 23.884205396491215,
#  'redshift_9': 0.0,
#  'moment_sigma_9': 1.9069267511367798,
#  'e1_9': 0.013869285583496094,
#  'e2_9': -0.13150247931480408,
#  'mag_10': 23.628458823100253,
#  'redshift_10': 0.0,
#  'moment_sigma_10': 3.029029607772827,
#  'e1_10': 0.0008806253899820149,
#  'e2_10': 0.031444210559129715,
#  'mag_11': 23.68229067713282,
#  'redshift_11': 0.0,
#  'moment_sigma_11': 2.5699377059936523,
#  'e1_11': -0.06647934019565582,
#  'e2_11': 0.1681574136018753,
#  'mag_12': 23.397747813168895,
#  'redshift_12': 0.0,
#  'moment_sigma_12': 3.7589309215545654,
#  'e1_12': -0.3085553050041199,
#  'e2_12': -0.12716414034366608,
#  'mag_13': 23.389370386334342,
#  'redshift_13': 0.0,
#  'moment_sigma_13': 1.9784400463104248,
#  'e1_13': 0.1542396992444992,
#  'e2_13': -0.1336738020181656,
#  'mag_14': 23.108139029566146,
#  'redshift_14': 0.0,
#  'moment_sigma_14': 2.5896081924438477,
#  'e1_14': 0.048794861882925034,
#  'e2_14': -0.12219887226819992,
#  'mag_15': 23.637101903165487,
#  'redshift_15': 0.0,
#  'moment_sigma_15': 2.4402198791503906,
#  'e1_15': 0.6043617129325867,
#  'e2_15': -0.13117803633213043,
#  'mag_16': 23.328345403728072,
#  'redshift_16': 0.0,
#  'moment_sigma_16': 2.8863515853881836,
#  'e1_16': 0.15713028609752655,
#  'e2_16': 0.19061024487018585,
#  'mag_17': 23.212741983327728,
#  'redshift_17': 0.0,
#  'moment_sigma_17': 2.953190326690674,
#  'e1_17': -0.343013733625412,
#  'e2_17': 0.5461072325706482,
#  'mag_18': 20.58378935893465,
#  'redshift_18': 0.0,
#  'moment_sigma_18': 3.129307746887207,
#  'e1_18': -0.1191006675362587,
#  'e2_18': 0.0443798191845417,
#  'mag_19': 21.390572093812835,
#  'redshift_19': 0.0,
#  'moment_sigma_19': 5.318264007568359,
#  'e1_19': 0.020534642040729523,
#  'e2_19': -0.031171707436442375,
#  'mag_20': 23.916747682958224,
#  'redshift_20': 0.0,
#  'moment_sigma_20': 3.091054916381836,
#  'e1_20': -0.30788302421569824,
#  'e2_20': 0.5191676020622253,
#  'mag_21': 23.212741983327728,
#  'redshift_21': 0.0,
#  'moment_sigma_21': 2.9541337490081787,
#  'e1_21': -0.34315794706344604,
#  'e2_21': 0.5464372038841248,
#  'mag_22': 22.961230365773066,
#  'redshift_22': 0.0,
#  'moment_sigma_22': 2.1379923820495605,
#  'e1_22': 0.2144554853439331,
#  'e2_22': -0.08422722667455673,
#  'mag_23': 23.937300331800035,
#  'redshift_23': 0.0,
#  'moment_sigma_23': 2.4860143661499023,
#  'e1_23': 0.14772437512874603,
#  'e2_23': -0.22040390968322754,
#  'mag_24': 23.512706271405325,
#  'redshift_24': 0.0,
#  'moment_sigma_24': 3.585336923599243,
#  'e1_24': -1.176466464996338,
#  'e2_24': -0.0738455131649971,
#  'mag_25': 22.232786989519532,
#  'redshift_25': 0.0,
#  'moment_sigma_25': 3.215613842010498,
#  'e1_25': -0.3111605644226074,
#  'e2_25': 0.3028656244277954,
#  'mag_26': 21.992756605630866,
#  'redshift_26': 0.0,
#  'moment_sigma_26': 2.926117420196533,
#  'e1_26': -0.2691441476345062,
#  'e2_26': 0.23924757540225983,
#  'mag_27': 23.385629042756754,
#  'redshift_27': 0.0,
#  'moment_sigma_27': 2.3858208656311035,
#  'e1_27': -0.03498171642422676,
#  'e2_27': 0.043023545295000076,
#  'mag_28': 23.89798591216256,
#  'redshift_28': 0.0,
#  'moment_sigma_28': 1.8675673007965088,
#  'e1_28': -0.38714680075645447,
#  'e2_28': 0.15703441202640533,
#  'mag_29': 23.51769579669724,
#  'redshift_29': 0.0,
#  'moment_sigma_29': 2.527831792831421,
#  'e1_29': 0.0936601459980011,
#  'e2_29': -0.1644017994403839,
#  'mag_30': 23.409828868731566,
#  'redshift_30': 0.0,
#  'moment_sigma_30': 3.2742724418640137,
#  'e1_30': -0.04672357439994812,
#  'e2_30': -0.044897980988025665,
#  'mag_31': 23.869383253111902,
#  'redshift_31': 0.0,
#  'moment_sigma_31': 2.5757782459259033,
#  'e1_31': 0.09507732838392258,
#  'e2_31': 0.11564137786626816,
#  'mag_32': 23.235713248549406,
#  'redshift_32': 0.0,
#  'moment_sigma_32': 2.822965621948242,
#  'e1_32': 0.006110804621130228,
#  'e2_32': -0.0466964989900589,
#  'mag_33': 23.937300331800035,
#  'redshift_33': 0.0,
#  'moment_sigma_33': 2.4862706661224365,
#  'e1_33': 0.14778047800064087,
#  'e2_33': -0.2203114628791809,
#  'mag_34': 23.37646236831838,
#  'redshift_34': 0.0,
#  'moment_sigma_34': 2.7673444747924805,
#  'e1_34': -0.06107989326119423,
#  'e2_34': -0.1547277420759201,
#  'mag_35': 23.346957161157295,
#  'redshift_35': 0.0,
#  'moment_sigma_35': 3.0270938873291016,
#  'e1_35': 0.17230795323848724,
#  'e2_35': -0.04255876690149307,
#  'mag_36': 23.661984405978508,
#  'redshift_36': 0.0,
#  'moment_sigma_36': 2.0651800632476807,
#  'e1_36': 0.007660063914954662,
#  'e2_36': 0.08603523671627045,
#  'mag_37': 23.83790204273633,
#  'redshift_37': 0.0,
#  'moment_sigma_37': 2.102670192718506,
#  'e1_37': 0.24320900440216064,
#  'e2_37': 0.10731220990419388,
#  'mag_38': 22.80797006142034,
#  'redshift_38': 0.0,
#  'moment_sigma_38': 1.954632043838501,
#  'e1_38': 0.06752341240644455,
#  'e2_38': 0.4179364740848541,
#  'mag_39': 23.256493870470045,
#  'redshift_39': 0.0,
#  'moment_sigma_39': 3.0380921363830566,
#  'e1_39': -0.07021885365247726,
#  'e2_39': 0.10070640593767166,
#  'mag_40': 22.470198536053545,
#  'redshift_40': 0.0,
#  'moment_sigma_40': 2.3806495666503906,
#  'e1_40': 0.17611101269721985,
#  'e2_40': 0.20573149621486664,
#  'mag_41': 23.962460499954098,
#  'redshift_41': 0.0,
#  'moment_sigma_41': 2.320183038711548,
#  'e1_41': 0.08815229684114456,
#  'e2_41': 0.13414718210697174,
#  'mag_42': 23.264213667550475,
#  'redshift_42': 0.0,
#  'moment_sigma_42': 2.7655599117279053,
#  'e1_42': -0.4508441388607025,
#  'e2_42': -0.03902522101998329,
#  'redshift_43': 10.0,
#  'moment_sigma_43': 10.0,
#  'e1_43': 10.0,
#  'e2_43': 10.0,
#  'mag_43': 10.0,
#  'redshift_44': 10.0,
#  'moment_sigma_44': 10.0,
#  'e1_44': 10.0,
#  'e2_44': 10.0,
#  'mag_44': 10.0,
#  'redshift_45': 10.0,
#  'moment_sigma_45': 10.0,
#  'e1_45': 10.0,
#  'e2_45': 10.0,
#  'mag_45': 10.0,
#  'redshift_46': 10.0,
#  'moment_sigma_46': 10.0,
#  'e1_46': 10.0,
#  'e2_46': 10.0,
#  'mag_46': 10.0,
#  'redshift_47': 10.0,
#  'moment_sigma_47': 10.0,
#  'e1_47': 10.0,
#  'e2_47': 10.0,
#  'mag_47': 10.0,
#  'redshift_48': 10.0,
#  'moment_sigma_48': 10.0,
#  'e1_48': 10.0,
#  'e2_48': 10.0,
#  'mag_48': 10.0,
#  'redshift_49': 10.0,
#  'moment_sigma_49': 10.0,
#  'e1_49': 10.0,
#  'e2_49': 10.0,
#  'mag_49': 10.0,
#  'redshift_50': 10.0,
#  'moment_sigma_50': 10.0,
#  'e1_50': 10.0,
#  'e2_50': 10.0,
#  'mag_50': 10.0,
#  'redshift_51': 10.0,
#  'moment_sigma_51': 10.0,
#  'e1_51': 10.0,
#  'e2_51': 10.0,
#  'mag_51': 10.0,
#  'redshift_52': 10.0,
#  'moment_sigma_52': 10.0,
#  'e1_52': 10.0,
#  'e2_52': 10.0,
#  'mag_52': 10.0,
#  'redshift_53': 10.0,
#  'moment_sigma_53': 10.0,
#  'e1_53': 10.0,
#  'e2_53': 10.0,
#  'mag_53': 10.0,
#  'redshift_54': 10.0,
#  'moment_sigma_54': 10.0,
#  'e1_54': 10.0,
#  'e2_54': 10.0,
#  'mag_54': 10.0,
#  'redshift_55': 10.0,
#  'moment_sigma_55': 10.0,
#  'e1_55': 10.0,
#  'e2_55': 10.0,
#  'mag_55': 10.0,
#  'redshift_56': 10.0,
#  'moment_sigma_56': 10.0,
#  'e1_56': 10.0,
#  'e2_56': 10.0,
#  'mag_56': 10.0,
#  'redshift_57': 10.0,
#  'moment_sigma_57': 10.0,
#  'e1_57': 10.0,
#  'e2_57': 10.0,
#  'mag_57': 10.0,
#  'redshift_58': 10.0,
#  'moment_sigma_58': 10.0,
#  'e1_58': 10.0,
#  'e2_58': 10.0,
#  'mag_58': 10.0,
#  'redshift_59': 10.0,
#  'moment_sigma_59': 10.0,
#  'e1_59': 10.0,
#  'e2_59': 10.0,
#  'mag_59': 10.0,
#  'redshift_60': 10.0,
#  'moment_sigma_60': 10.0,
#  'e1_60': 10.0,
#  'e2_60': 10.0,
#  'mag_60': 10.0,
#  'redshift_61': 10.0,
#  'moment_sigma_61': 10.0,
#  'e1_61': 10.0,
#  'e2_61': 10.0,
#  'mag_61': 10.0,
#  'redshift_62': 10.0,
#  'moment_sigma_62': 10.0,
#  'e1_62': 10.0,
#  'e2_62': 10.0,
#  'mag_62': 10.0,
#  'redshift_63': 10.0,
#  'moment_sigma_63': 10.0,
#  'e1_63': 10.0,
#  'e2_63': 10.0,
#  'mag_63': 10.0,
#  'redshift_64': 10.0,
#  'moment_sigma_64': 10.0,
#  'e1_64': 10.0,
#  'e2_64': 10.0,
#  'mag_64': 10.0,
#  'redshift_65': 10.0,
#  'moment_sigma_65': 10.0,
#  'e1_65': 10.0,
#  'e2_65': 10.0,
#  'mag_65': 10.0,
#  'redshift_66': 10.0,
#  'moment_sigma_66': 10.0,
#  'e1_66': 10.0,
#  'e2_66': 10.0,
#  'mag_66': 10.0,
#  'redshift_67': 10.0,
#  'moment_sigma_67': 10.0,
#  'e1_67': 10.0,
#  'e2_67': 10.0,
#  'mag_67': 10.0,
#  'redshift_68': 10.0,
#  'moment_sigma_68': 10.0,
#  'e1_68': 10.0,
#  'e2_68': 10.0,
#  'mag_68': 10.0,
#  'redshift_69': 10.0,
#  'moment_sigma_69': 10.0,
#  'e1_69': 10.0,
#  'e2_69': 10.0,
#  'mag_69': 10.0,
#  'redshift_70': 10.0,
#  'moment_sigma_70': 10.0,
#  'e1_70': 10.0,
#  'e2_70': 10.0,
#  'mag_70': 10.0,
#  'redshift_71': 10.0,
#  'moment_sigma_71': 10.0,
#  'e1_71': 10.0,
#  'e2_71': 10.0,
#  'mag_71': 10.0,
#  'redshift_72': 10.0,
#  'moment_sigma_72': 10.0,
#  'e1_72': 10.0,
#  'e2_72': 10.0,
#  'mag_72': 10.0,
#  'redshift_73': 10.0,
#  'moment_sigma_73': 10.0,
#  'e1_73': 10.0,
#  'e2_73': 10.0,
#  'mag_73': 10.0,
#  'redshift_74': 10.0,
#  'moment_sigma_74': 10.0,
#  'e1_74': 10.0,
#  'e2_74': 10.0,
#  'mag_74': 10.0,
#  'redshift_75': 10.0,
#  'moment_sigma_75': 10.0,
#  'e1_75': 10.0,
#  'e2_75': 10.0,
#  'mag_75': 10.0,
#  'redshift_76': 10.0,
#  'moment_sigma_76': 10.0,
#  'e1_76': 10.0,
#  'e2_76': 10.0,
#  'mag_76': 10.0,
#  'redshift_77': 10.0,
#  'moment_sigma_77': 10.0,
#  'e1_77': 10.0,
#  'e2_77': 10.0,
#  'mag_77': 10.0,
#  'redshift_78': 10.0,
#  'moment_sigma_78': 10.0,
#  'e1_78': 10.0,
#  'e2_78': 10.0,
#  'mag_78': 10.0,
#  'redshift_79': 10.0,
#  'moment_sigma_79': 10.0,
#  'e1_79': 10.0,
#  'e2_79': 10.0,
#  'mag_79': 10.0,
#  'redshift_80': 10.0,
#  'moment_sigma_80': 10.0,
#  'e1_80': 10.0,
#  'e2_80': 10.0,
#  'mag_80': 10.0,
#  'redshift_81': 10.0,
#  'moment_sigma_81': 10.0,
#  'e1_81': 10.0,
#  'e2_81': 10.0,
#  'mag_81': 10.0,
#  'redshift_82': 10.0,
#  'moment_sigma_82': 10.0,
#  'e1_82': 10.0,
#  'e2_82': 10.0,
#  'mag_82': 10.0,
#  'redshift_83': 10.0,
#  'moment_sigma_83': 10.0,
#  'e1_83': 10.0,
#  'e2_83': 10.0,
#  'mag_83': 10.0,
#  'redshift_84': 10.0,
#  'moment_sigma_84': 10.0,
#  'e1_84': 10.0,
#  'e2_84': 10.0,
#  'mag_84': 10.0,
#  'redshift_85': 10.0,
#  'moment_sigma_85': 10.0,
#  'e1_85': 10.0,
#  'e2_85': 10.0,
#  'mag_85': 10.0,
#  'redshift_86': 10.0,
#  'moment_sigma_86': 10.0,
#  'e1_86': 10.0,
#  'e2_86': 10.0,
#  'mag_86': 10.0,
#  'redshift_87': 10.0,
#  'moment_sigma_87': 10.0,
#  'e1_87': 10.0,
#  'e2_87': 10.0,
#  'mag_87': 10.0,
#  'redshift_88': 10.0,
#  'moment_sigma_88': 10.0,
#  'e1_88': 10.0,
#  'e2_88': 10.0,
#  'mag_88': 10.0,
#  'redshift_89': 10.0,
#  'moment_sigma_89': 10.0,
#  'e1_89': 10.0,
#  'e2_89': 10.0,
#  'mag_89': 10.0,
#  'redshift_90': 10.0,
#  'moment_sigma_90': 10.0,
#  'e1_90': 10.0,
#  'e2_90': 10.0,
#  'mag_90': 10.0,
#  'redshift_91': 10.0,
#  'moment_sigma_91': 10.0,
#  'e1_91': 10.0,
#  'e2_91': 10.0,
#  'mag_91': 10.0,
#  'redshift_92': 10.0,
#  'moment_sigma_92': 10.0,
#  'e1_92': 10.0,
#  'e2_92': 10.0,
#  'mag_92': 10.0,
#  'redshift_93': 10.0,
#  'moment_sigma_93': 10.0,
#  'e1_93': 10.0,
#  'e2_93': 10.0,
#  'mag_93': 10.0,
#  'redshift_94': 10.0,
#  'moment_sigma_94': 10.0,
#  'e1_94': 10.0,
#  'e2_94': 10.0,
#  'mag_94': 10.0,
#  'redshift_95': 10.0,
#  'moment_sigma_95': 10.0,
#  'e1_95': 10.0,
#  'e2_95': 10.0,
#  'mag_95': 10.0,
#  'nb_blended_gal': 43,
#  'mag': 21.643046070746873,
#  'mag_ir': -5.757114604789912,
#  'closest_mag': 23.83790204273633,
#  'closest_mag_ir': -3.091069264455868,
#  'closest_x': 3.5150650269656794,
#  'closest_y': 0.6967720499858103,
#  'idx_closest_to_peak': 0,
#  'n_peak_detected': 1,
#  'SNR': 1746.7883468803338,
#  'SNR_peak': 2.3938636456923295}

# %%
print(str(res[2]['nb_blended_gal'])+' galaxies are added to this image.')
# Out:
# 43 galaxies are added to this image.

# %%
fig, ax = plt.subplots(1,2, figsize =(20,10))
ax[0].imshow(res[0][6])
ax[1].imshow(res[1][6], vmax = 10000)

# %%
bands = [7,6,5] # Plot ugrizy

fig = plt.figure(figsize = (10,10))

plot.plot_rgb(res[1]/(np.max(res[1][4:])/10), bands = bands,ax= None, band_first = True,zoom = 1, clip = False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
bands = [7,6,5] # Plot ugrizy
pixel_scale_lsst = 0.2 # arcsec/pix
fig = plt.figure(figsize = (10,10))

plot.plot_rgb(res[1]/(np.max(res[1][4:])/10), bands = bands,ax= None, band_first = True,zoom = 1, shifts = res[3]/pixel_scale_lsst, clip = False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
